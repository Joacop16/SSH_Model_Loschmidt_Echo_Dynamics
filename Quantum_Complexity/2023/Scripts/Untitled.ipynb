# %%
import Functions

# %%
import Derivadas_1
import Derivadas_2
import Derivadas_3

# %%
funciones = [Derivadas_1.f_0,Derivadas_1.f_1,Derivadas_1.f_2,Derivadas_1.f_3,Derivadas_1.f_4,Derivadas_1.f_5,Derivadas_1.f_6,Derivadas_1.f_7,Derivadas_1.f_8,Derivadas_1.f_9,Derivadas_1.f_10,Derivadas_1.f_11,Derivadas_1.f_12,Derivadas_1.f_13,Derivadas_1.f_14]

# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
tiempos =  np.linspace(-2,2,50)

# %%
for f in funciones:
    plt.plot(tiempos, f(tiempos))

# %%
funciones = [Derivadas_2.f_0,Derivadas_2.f_1,Derivadas_2.f_2,Derivadas_2.f_3,Derivadas_2.f_4,Derivadas_2.f_5,Derivadas_2.f_6,Derivadas_2.f_7,Derivadas_2.f_8,Derivadas_2.f_9,Derivadas_2.f_10,Derivadas_2.f_11,Derivadas_2.f_12,Derivadas_2.f_13,Derivadas_2.f_14,Derivadas_2.f_15,Derivadas_2.f_16]

# %%
for f in funciones:
    plt.plot(tiempos, f(tiempos))

# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
import Derivadas_3

# %%
tiempos =  np.linspace(-2,2,10)

# %%
plt.plot(tiempos, Derivadas_3.f_12(tiempos))
